# %% [markdown]
# # Skip-gram word2vec
#
# This notebook presents a TensorFlow implemention of the word2vec algorithm using the skip-gram architecture.
#
# ## Links
#
# I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
# * [Using Word Embeddings](https://github.com/fchollet/deep-learning-with-python-notebooks/blob/master/6.1-using-word-embeddings.ipynb)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

#import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile
import re
from collections import Counter


dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

def create_lookup_tables(words):
    """
    Create lookup tables for vocabulary
    :param words: Input list of words
    :return: A tuple of dicts.  The first dict....
    """
    word_counts = Counter(words)
    sorted_vocab = sorted(word_counts, key=word_counts.get, reverse=True)
    int_to_vocab = {ii: word for ii, word in enumerate(sorted_vocab)}
    vocab_to_int = {word: ii for ii, word in int_to_vocab.items()}

    return vocab_to_int, int_to_vocab

def preprocess(text):

    # Replace punctuation with tokens so we can use them in our model
    text = text.lower()
    text = text.replace('.', ' <PERIOD> ')
    text = text.replace(',', ' <COMMA> ')
    text = text.replace('"', ' <QUOTATION_MARK> ')
    text = text.replace(';', ' <SEMICOLON> ')
    text = text.replace('!', ' <EXCLAMATION_MARK> ')
    text = text.replace('?', ' <QUESTION_MARK> ')
    text = text.replace('(', ' <LEFT_PAREN> ')
    text = text.replace(')', ' <RIGHT_PAREN> ')
    text = text.replace('--', ' <HYPHENS> ')
    text = text.replace('?', ' <QUESTION_MARK> ')
    # text = text.replace('\n', ' <NEW_LINE> ')
    text = text.replace(':', ' <COLON> ')
    words = text.split()
    
    # Remove all words with  5 or fewer occurences
    word_counts = Counter(words)
    trimmed_words = [word for word in words if word_counts[word] > 5]

    return trimmed_words

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    #inputs = tf.placeholder(tf.int32, [None], name='inputs')
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  300
with tf.device('/cpu:0'):
 with train_graph.as_default():
     embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
     embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output
# Out:
# WARNING:tensorflow:From C:\Users\lenovo lappy\.conda\envs\keras-gpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding))) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab), name="softmax_bias") # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(
        weights=softmax_w,
        biases=softmax_b,
        labels=labels,
        inputs=embed,
        num_sampled=n_sampled,
        num_classes=n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From C:\Users\lenovo lappy\.conda\envs\keras-gpu\lib\site-packages\tensorflow\python\ops\nn_impl.py:1444: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From C:\Users\lenovo lappy\.conda\envs\keras-gpu\lib\site-packages\tensorflow\python\ops\array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-12-2aa168c49a56>:13: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# A subdirectory or file checkpoints already exists.

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            
            feed = {inputs: x,
            labels: np.array(y)[:, None]}
            _, train_loss = sess.run([optimizer, cost], feed_dict=feed)
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 21.6918 0.2987 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 21.3973 0.2936 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 21.1274 0.2941 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 21.1627 0.2934 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 20.9062 0.2937 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 20.8022 0.2933 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 20.7433 0.2940 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 20.5502 0.2929 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 20.4043 0.2938 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 20.2269 0.2931 sec/batch
# Nearest to for: shane, baez, kanpur, egypt, standardise, mimic, tirana, beaked,
# Nearest to history: guild, lift, lampoon, interpretive, wad, philistia, staden, hellenistic,
# Nearest to been: acceded, knock, ludwik, instructional, etta, taxonomic, entrepreneurial, boomed,
# Nearest to as: hasek, objections, disappear, humanly, ddt, infamous, confluence, kermit,
# Nearest to his: superceded, uneventful, virchow, misinformation, receipt, chagi, krag, malt,
# Nearest to where: sentimental, telekom, iraq, jr, neverwinter, acetylsalicylic, fianna, tournament,
# Nearest to however: psalms, looting, ecusa, yellow, chloride, vets, galvanized, hinged,
# Nearest to which: jedi, brewer, supersede, cii, maguey, lombardo, pontic, marchant,
# Nearest to alternative: blissymbolics, ying, bat, routed, wyoming, moorish, jati, libyans,
# Nearest to event: turing, gothicus, basf, chara, iotation, ethicists, thirtieth, powerpuff,
# Nearest to ice: procurator, volhynia, desktop, kafir, looters, connoisseurs, guayas, harmondsworth,
# Nearest to heavy: gravelines, agavaceae, kulm, relegate, vesa, classless, appended, gigi,
# Nearest to powers: feel, masoretic, boils, marek, hautes, coveted, jailer, carmakers,
# Nearest to accepted: dinners, cheka, romanis, starfleet, eastman, pedigree, nta, haiku,
# Nearest to brother: haeckel, kahului, leeward, st, hardline, detergents, jemima, collimated,
# Nearest to universe: updike, heap, hbp, decade, abundantly, atmospheric, p, galaxies,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 20.1771 0.2956 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 20.0577 0.2935 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 19.8516 0.2931 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 19.7793 0.2931 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 19.6383 0.2931 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 19.4986 0.2934 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 19.4312 0.2929 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 19.2951 0.2937 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 19.2270 0.2928 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 19.0578 0.2938 sec/batch
# Nearest to for: shane, baez, mimic, kanpur, standardise, egypt, pierre, beaked,
# Nearest to history: guild, lift, lampoon, interpretive, hellenistic, philistia, wad, staden,
# Nearest to been: acceded, knock, ludwik, instructional, taxonomic, etta, boomed, entrepreneurial,
# Nearest to as: hasek, objections, disappear, infamous, humanly, ddt, kermit, dcsd,
# Nearest to his: superceded, misinformation, virchow, uneventful, receipt, chagi, malt, resumed,
# Nearest to where: sentimental, telekom, iraq, jr, zubrin, fianna, photosystem, tournament,
# Nearest to however: looting, psalms, ecusa, yellow, trang, vets, chloride, bus,
# Nearest to which: jedi, brewer, supersede, cii, lombardo, marchant, pontic, maguey,
# Nearest to alternative: blissymbolics, ying, bat, routed, jati, libyans, wyoming, moorish,
# Nearest to event: iotation, chara, turing, basf, gothicus, powerpuff, denominated, ethicists,
# Nearest to ice: procurator, volhynia, kafir, looters, desktop, scandinavian, canvas, connoisseurs,
# Nearest to heavy: gravelines, agavaceae, relegate, classless, vesa, kulm, issuer, pytheas,
# Nearest to powers: masoretic, feel, boils, marek, coveted, carmakers, hautes, jastrow,
# Nearest to accepted: dinners, cheka, starfleet, romanis, eastman, protocols, pedigree, replied,
# Nearest to brother: haeckel, kahului, leeward, hardline, st, janie, collimated, jemima,
# Nearest to universe: updike, heap, hbp, decade, galaxies, atmospheric, abundantly, anglia,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 18.9409 0.2952 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 18.9325 0.2929 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 18.7309 0.2938 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 18.6473 0.2932 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 18.6050 0.2931 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 18.4827 0.2935 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 18.3535 0.2936 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 18.2447 0.2931 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 18.1195 0.2937 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 18.0516 0.2934 sec/batch
# Nearest to for: baez, shane, mimic, standardise, kanpur, egypt, acoustical, subexpression,
# Nearest to history: guild, lift, lampoon, interpretive, hellenistic, philistia, wad, dll,
# Nearest to been: acceded, knock, ludwik, instructional, boomed, taxonomic, etta, dedication,
# Nearest to as: hasek, objections, disappear, infamous, humanly, introspection, dcsd, kermit,
# Nearest to his: superceded, misinformation, virchow, chagi, uneventful, receipt, kournikova, livres,
# Nearest to where: sentimental, jr, telekom, iraq, zubrin, tran, photosystem, fianna,
# Nearest to however: looting, psalms, yellow, ecusa, trang, galvanized, oviedo, nate,
# Nearest to which: jedi, supersede, brewer, maguey, lombardo, designated, cii, claimant,
# Nearest to alternative: blissymbolics, ying, bat, routed, jati, wyoming, deadites, libyans,
# Nearest to event: turing, iotation, chara, basf, gothicus, powerpuff, mariel, depressive,
# Nearest to ice: procurator, volhynia, looters, kafir, desktop, canvas, northcote, torrents,
# Nearest to heavy: gravelines, agavaceae, classless, kulm, vesa, relegate, issuer, appended,
# Nearest to powers: masoretic, boils, feel, marek, coveted, carmakers, sarcophagi, underpowered,
# Nearest to accepted: dinners, starfleet, cheka, romanis, eastman, replied, protocols, nta,
# Nearest to brother: haeckel, kahului, hardline, leeward, st, fukuyama, jemima, relatives,
# Nearest to universe: updike, heap, hbp, galaxies, decade, abundantly, atmospheric, weight,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 17.9025 0.2956 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 17.7539 0.2937 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 17.6593 0.2933 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 17.5581 0.2931 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 17.4853 0.2941 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 17.4645 0.2943 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 17.3972 0.2935 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 17.2670 0.2935 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 17.2213 0.2931 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 17.0623 0.2931 sec/batch
# Nearest to for: baez, mimic, shane, subexpression, standardise, acoustical, kanpur, egypt,
# Nearest to history: guild, lift, interpretive, lampoon, dll, staden, wad, hounded,
# Nearest to been: acceded, ludwik, knock, boomed, etta, ludd, dedication, instructional,
# Nearest to as: hasek, objections, disappear, introspection, infamous, humanly, stillborn, dcsd,
# Nearest to his: superceded, misinformation, uneventful, livres, receipt, warned, chagi, virchow,
# Nearest to where: sentimental, telekom, jr, irvine, zubrin, tran, barker, iraq,
# Nearest to however: looting, psalms, yellow, ecusa, trang, brocklin, oviedo, stomping,
# Nearest to which: jedi, brewer, supersede, maguey, cii, marchant, tabriz, designated,
# Nearest to alternative: blissymbolics, ying, bat, libyans, hc, routed, jati, wyoming,
# Nearest to event: turing, chara, iotation, gothicus, basf, depressive, denominated, mariel,
# Nearest to ice: procurator, kafir, desktop, volhynia, looters, canvas, torrents, northcote,
# Nearest to heavy: gravelines, classless, agavaceae, relegate, kulm, vesa, appended, issuer,
# Nearest to powers: masoretic, boils, marek, carmakers, feel, coveted, underpowered, sarcophagi,
# Nearest to accepted: starfleet, cheka, dinners, romanis, pedigree, eastman, diseased, replied,
# Nearest to brother: haeckel, relatives, leeward, hardline, kahului, detergents, janie, jemima,
# Nearest to universe: updike, heap, hbp, galaxies, abundantly, decade, weight, atmospheric,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 17.0695 0.2947 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 16.7782 0.2933 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 16.7556 0.2941 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 16.7135 0.2935 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 16.5825 0.2937 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 16.5122 0.2930 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 16.3721 0.2209 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 16.1868 0.2933 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 16.0753 0.2938 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 15.9420 0.2937 sec/batch
# Nearest to for: baez, acoustical, mimic, erskine, subexpression, egypt, teos, marcos,
# Nearest to history: guild, lampoon, interpretive, lift, dll, hounded, staden, wad,
# Nearest to been: acceded, ludwik, knock, boomed, whitefish, dedication, etta, scapa,
# Nearest to as: hasek, objections, stillborn, disappear, introspection, infamous, dcsd, assembling,
# Nearest to his: superceded, misinformation, livres, resumed, receipt, chagi, sensitivity, warned,
# Nearest to where: sentimental, telekom, irvine, fianna, barker, jr, zubrin, photosystem,
# Nearest to however: looting, psalms, yellow, ecusa, brocklin, nate, trang, senussi,
# Nearest to which: jedi, brewer, toys, pontic, sholay, supersede, claimant, marchant,
# Nearest to alternative: ying, blissymbolics, bat, routed, hc, libyans, jati, deadites,
# Nearest to event: iotation, turing, gothicus, chara, basf, denominated, pledged, ethicists,
# Nearest to ice: procurator, desktop, kafir, looters, canvas, volhynia, eridanus, northcote,
# Nearest to heavy: classless, agavaceae, gravelines, kulm, vesa, appended, relegate, finsbury,
# Nearest to powers: masoretic, marek, boils, carmakers, feel, coveted, underpowered, sarcophagi,
# Nearest to accepted: starfleet, cheka, dinners, romanis, pedigree, eastman, replied, diseased,
# Nearest to brother: haeckel, leeward, relatives, hardline, collimated, detergents, jemima, kahului,
# Nearest to universe: updike, heap, hbp, abundantly, galaxies, guimar, pharaohs, atmospheric,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 15.9402 0.2952 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 15.8328 0.2936 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 15.7165 0.2933 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 15.6540 0.2933 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 15.5338 0.2931 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 15.3953 0.2935 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 15.3408 0.2933 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 15.2066 0.2936 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 15.1433 0.2932 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 15.1673 0.2926 sec/batch
# Nearest to for: to, the, acoustical, and, havilland, of, has, subexpression,
# Nearest to history: guild, approving, stool, dll, pyrimidines, lift, sum, interpretive,
# Nearest to been: acceded, ludwik, whitefish, gimlin, knock, dedication, boomed, spondees,
# Nearest to as: of, objections, pain, restorer, dcsd, introspection, smiles, manicheanism,
# Nearest to his: superceded, misinformation, resumed, livres, sensitivity, intoxicated, warned, ladin,
# Nearest to where: sentimental, irvine, telekom, jr, fianna, tran, photosystem, choosing,
# Nearest to however: psalms, looting, yellow, ecusa, titular, lonely, brocklin, senussi,
# Nearest to which: jedi, the, brewer, new, toys, sholay, designated, previous,
# Nearest to alternative: ying, blissymbolics, bat, hc, routed, jati, libyans, deadites,
# Nearest to event: chara, gothicus, iotation, turing, depressive, ethicists, maid, pledged,
# Nearest to ice: procurator, kafir, desktop, looters, canvas, eridanus, northcote, volhynia,
# Nearest to heavy: classless, kulm, agavaceae, gravelines, vesa, relegate, finsbury, nobuo,
# Nearest to powers: masoretic, boils, carmakers, marek, sarcophagi, feel, underpowered, coveted,
# Nearest to accepted: starfleet, dinners, cheka, romanis, replied, pedigree, chalker, delgada,
# Nearest to brother: haeckel, hardline, leeward, relatives, casablanca, collimated, unambiguous, janie,
# Nearest to universe: updike, heap, hbp, atmospheric, galaxies, guimar, congratulate, anglia,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 15.1806 0.2951 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 14.9518 0.2936 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 14.8972 0.2937 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 14.8181 0.2932 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 14.8088 0.2932 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 14.7537 0.2937 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 14.5744 0.2936 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 14.5217 0.2929 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 14.4486 0.2932 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 14.3916 0.2940 sec/batch
# Nearest to for: to, the, and, is, of, in, a, by,
# Nearest to history: lift, sum, guild, saboteur, stool, approving, two, additive,
# Nearest to been: acceded, ludwik, gimlin, whitefish, moldovan, knock, boomed, dedication,
# Nearest to as: to, of, the, a, and, is, in, with,
# Nearest to his: superceded, livres, misinformation, of, europeans, resumed, warned, receipt,
# Nearest to where: irvine, sentimental, telekom, medicinal, jr, tran, choosing, zubrin,
# Nearest to however: looting, psalms, yellow, as, titular, brocklin, cale, ecusa,
# Nearest to which: the, of, and, a, is, to, by, for,
# Nearest to alternative: ying, bat, blissymbolics, routed, hc, jati, wyoming, libyans,
# Nearest to event: chara, iotation, maid, turing, gothicus, denominated, depressive, tekken,
# Nearest to ice: procurator, kafir, desktop, looters, canvas, eridanus, volhynia, haemoglobin,
# Nearest to heavy: kulm, gravelines, agavaceae, classless, vesa, nobuo, relegate, pinckney,
# Nearest to powers: masoretic, carmakers, boils, feel, marek, sarcophagi, underpowered, costly,
# Nearest to accepted: starfleet, cheka, dinners, romanis, replied, diseased, nta, delgada,
# Nearest to brother: haeckel, hardline, leeward, relatives, collimated, unambiguous, casablanca, janie,
# Nearest to universe: updike, heap, hbp, weight, galaxies, congratulate, locked, pharaohs,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 14.3589 0.2946 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 14.2332 0.2936 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 14.0291 0.2934 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 14.0115 0.2936 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 13.9959 0.2930 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 13.9366 0.2940 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 13.7891 0.2933 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 13.8145 0.2934 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 13.5945 0.2935 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 13.5127 0.2926 sec/batch
# Nearest to for: the, in, of, a, to, and, that, with,
# Nearest to history: three, lift, two, octal, stool, sum, work, hepburn,
# Nearest to been: on, ludwik, acceded, a, which, of, one, angelos,
# Nearest to as: to, of, the, that, and, a, in, is,
# Nearest to his: s, and, at, was, the, in, livres, that,
# Nearest to where: an, jr, from, barker, as, irvine, zubrin, sentimental,
# Nearest to however: and, the, it, was, be, by, in, for,
# Nearest to which: and, the, to, of, a, for, by, as,
# Nearest to alternative: ying, bat, hc, blissymbolics, jati, routed, libyans, wyoming,
# Nearest to event: iotation, chara, denominated, maid, turing, tekken, gothicus, heifer,
# Nearest to ice: procurator, looters, torrents, eridanus, kcr, canvas, kafir, wycliffe,
# Nearest to heavy: kulm, vesa, nobuo, classless, relegate, agavaceae, gravelines, issuer,
# Nearest to powers: masoretic, boils, underpowered, niv, costly, feel, marek, concentration,
# Nearest to accepted: starfleet, cheka, romanis, nta, replied, cvd, delgada, dinners,
# Nearest to brother: haeckel, hardline, relatives, leeward, casablanca, collimated, unambiguous, janie,
# Nearest to universe: updike, hbp, heap, weight, rgya, atmospheric, grand, congratulate,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 13.5289 0.2957 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 13.6377 0.2940 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 13.5507 0.2941 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 13.3977 0.2933 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 13.3552 0.2932 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 13.0918 0.2932 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 13.3372 0.2922 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 13.1356 0.2931 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 12.9466 0.2933 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 12.9782 0.2940 sec/batch
# Nearest to for: of, a, and, the, in, to, as, is,
# Nearest to history: was, for, of, and, to, the, eight, new,
# Nearest to been: of, has, s, by, the, to, also, it,
# Nearest to as: of, in, the, to, a, and, for, was,
# Nearest to his: was, s, he, to, on, an, that, of,
# Nearest to where: it, an, that, a, to, in, from, of,
# Nearest to however: as, to, for, are, by, is, and, the,
# Nearest to which: the, to, of, as, an, be, this, a,
# Nearest to alternative: ying, bat, libyans, support, hc, blissymbolics, jati, remarriage,
# Nearest to event: chara, iotation, pledged, turing, maid, denominated, heifer, troyes,
# Nearest to ice: procurator, looters, torrents, canvas, wycliffe, eridanus, kcr, kafir,
# Nearest to heavy: kulm, vesa, gravelines, classless, nobuo, agavaceae, relegate, pinckney,
# Nearest to powers: masoretic, costly, jastrow, concentration, underpowered, feel, boils, marek,
# Nearest to accepted: starfleet, romanis, lethargy, delgada, bishop, cheka, chalker, cvd,
# Nearest to brother: haeckel, hardline, between, leeward, relatives, collimated, janie, mourning,
# Nearest to universe: updike, hbp, heap, grand, weight, rgya, abundantly, observer,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 13.0353 0.2950 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 12.9508 0.2939 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 12.8142 0.1471 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 12.6783 0.2940 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 12.5507 0.2933 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 12.6018 0.2943 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 12.5179 0.2932 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 12.4264 0.2931 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 12.3436 0.2940 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 12.1014 0.2932 sec/batch
# Nearest to for: the, a, of, and, to, in, with, s,
# Nearest to history: new, to, have, nine, one, s, by, were,
# Nearest to been: of, by, to, has, the, and, it, from,
# Nearest to as: of, the, in, to, is, that, be, a,
# Nearest to his: he, of, was, s, by, at, to, the,
# Nearest to where: the, this, a, an, in, many, from, it,
# Nearest to however: this, to, the, are, of, in, by, that,
# Nearest to which: to, of, with, this, that, in, is, but,
# Nearest to alternative: ying, support, bat, libyans, serious, remarriage, jati, hc,
# Nearest to event: iotation, chara, maid, gift, turing, denominated, pledged, heifer,
# Nearest to ice: procurator, looters, canvas, wycliffe, torrents, kcr, damascius, oxidation,
# Nearest to heavy: vesa, kulm, gravelines, nobuo, classless, relegate, agavaceae, uncompetitive,
# Nearest to powers: masoretic, jastrow, concentration, feel, costly, underpowered, facing, custodians,
# Nearest to accepted: starfleet, lethargy, delgada, reconcile, distinct, chalker, viewed, monkhouse,
# Nearest to brother: haeckel, relatives, casablanca, leeward, guardia, hardline, st, locomotion,
# Nearest to universe: updike, hbp, heap, grand, observer, weight, abundantly, jocks,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 12.1851 0.2954 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 12.1492 0.2929 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 11.9492 0.2935 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 11.7133 0.2933 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 11.8295 0.2939 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 11.7991 0.2927 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 12.0689 0.2926 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 11.7294 0.2937 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 11.6609 0.2933 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 11.7138 0.2938 sec/batch
# Nearest to for: to, of, in, the, is, a, has, it,
# Nearest to history: the, nine, of, one, on, was, in, six,
# Nearest to been: the, and, in, it, has, of, for, as,
# Nearest to as: the, in, of, is, and, to, a, with,
# Nearest to his: he, the, of, and, s, was, in, at,
# Nearest to where: the, a, that, and, in, for, at, is,
# Nearest to however: the, of, to, for, is, has, a, other,
# Nearest to which: the, that, to, is, of, it, this, are,
# Nearest to alternative: support, ying, bat, serious, which, libyans, once, hc,
# Nearest to event: iotation, gift, pledged, maid, tekken, heifer, whatever, tested,
# Nearest to ice: procurator, looters, canvas, kcr, torrents, pardon, wycliffe, haemoglobin,
# Nearest to heavy: kulm, vesa, gravelines, slow, classless, equator, nobuo, pinckney,
# Nearest to powers: masoretic, costly, strength, produces, feel, concentration, jastrow, facing,
# Nearest to accepted: delgada, distinct, chalker, cruijff, starfleet, cheka, viewed, monkhouse,
# Nearest to brother: haeckel, relatives, unambiguous, small, locomotion, peril, mourning, leeward,
# Nearest to universe: updike, hbp, heap, weight, observer, grand, jocks, faded,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 11.6146 0.2946 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 11.6215 0.2938 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 11.2735 0.2936 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 11.3483 0.2933 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 11.3349 0.2929 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 11.2016 0.2936 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 11.2342 0.2935 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 11.3608 0.2927 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 10.8953 0.2939 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 11.1666 0.2931 sec/batch
# Nearest to for: to, a, the, and, that, in, of, as,
# Nearest to history: the, was, of, it, in, two, on, new,
# Nearest to been: and, a, the, that, in, on, has, have,
# Nearest to as: to, the, and, in, a, that, of, for,
# Nearest to his: he, the, was, in, of, and, s, who,
# Nearest to where: as, to, a, is, the, that, be, its,
# Nearest to however: that, a, to, it, the, of, for, other,
# Nearest to which: that, to, a, the, in, it, of, or,
# Nearest to alternative: support, ying, serious, bat, use, he, particular, bishops,
# Nearest to event: whatever, gift, tekken, chara, iotation, maid, heifer, turing,
# Nearest to ice: procurator, looters, canvas, wycliffe, pardon, oxidation, artistry, torrents,
# Nearest to heavy: kulm, vesa, equator, classless, gravelines, nobuo, slow, policies,
# Nearest to powers: strength, masoretic, costly, produces, feel, jastrow, simply, lyman,
# Nearest to accepted: them, that, distinct, delgada, today, monkhouse, legacy, cruijff,
# Nearest to brother: haeckel, relatives, unambiguous, locomotion, integrated, casablanca, lists, mourning,
# Nearest to universe: updike, weight, observer, p, grand, faded, hbp, heap,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 11.1285 0.2955 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 10.8567 0.2938 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 10.9043 0.2937 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 10.8957 0.2932 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 10.6917 0.2936 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 10.6635 0.2926 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 10.5672 0.2932 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 10.7912 0.2946 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 10.6966 0.2938 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 10.6417 0.2949 sec/batch
# Nearest to for: the, and, to, in, of, that, as, been,
# Nearest to history: and, of, the, in, to, on, for, under,
# Nearest to been: to, in, for, the, of, and, that, many,
# Nearest to as: the, that, and, to, in, of, it, for,
# Nearest to his: he, was, of, and, had, the, in, who,
# Nearest to where: a, in, the, of, to, is, as, from,
# Nearest to however: to, the, that, not, in, for, as, and,
# Nearest to which: as, to, not, and, that, for, the, in,
# Nearest to alternative: support, had, ying, serious, while, system, particular, since,
# Nearest to event: gift, back, whatever, last, tekken, but, army, iotation,
# Nearest to ice: procurator, looters, canvas, haemoglobin, kcr, oxidation, combined, pardon,
# Nearest to heavy: kulm, resistance, regency, equator, vesa, slow, policies, classless,
# Nearest to powers: strength, costly, simply, government, large, produces, executive, size,
# Nearest to accepted: until, from, people, and, been, in, of, the,
# Nearest to brother: haeckel, integrated, relatives, saw, m, mourning, unambiguous, st,
# Nearest to universe: updike, observer, weight, faded, grand, hbp, p, heap,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 10.8034 0.2946 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 10.1529 0.2941 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 10.5580 0.2924 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 10.3982 0.2933 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 10.1360 0.2934 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 10.3009 0.2934 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 10.3012 0.2937 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 10.2399 0.2932 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 10.2413 0.0738 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 10.0096 0.2932 sec/batch
# Nearest to for: the, of, all, a, to, it, as, on,
# Nearest to history: the, of, and, as, to, was, in, during,
# Nearest to been: the, to, of, was, and, a, in, on,
# Nearest to as: the, a, and, in, of, to, with, it,
# Nearest to his: was, he, had, until, to, of, s, in,
# Nearest to where: the, to, it, a, not, is, that, as,
# Nearest to however: the, to, it, as, of, all, not, or,
# Nearest to which: a, the, of, for, that, in, to, all,
# Nearest to alternative: local, did, support, addition, has, ying, between, famous,
# Nearest to event: ii, out, were, left, but, because, be, army,
# Nearest to ice: procurator, looters, canvas, combined, haemoglobin, pardon, kcr, oxidation,
# Nearest to heavy: regency, equator, resistance, slow, vesa, kulm, policies, artillery,
# Nearest to powers: government, since, large, lower, most, during, war, all,
# Nearest to accepted: than, work, the, in, under, each, until, found,
# Nearest to brother: haeckel, continued, st, another, integrated, thousands, with, a,
# Nearest to universe: observer, updike, faded, j, heap, jocks, existed, formulated,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 10.0440 0.2959 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 10.1039 0.2938 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 9.9266 0.2938 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 10.0081 0.2931 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 9.7942 0.2940 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 9.6159 0.2932 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 9.7093 0.2932 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 9.7660 0.2934 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 9.6106 0.2932 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 9.2611 0.2940 sec/batch
# Nearest to for: a, to, of, that, the, and, in, with,
# Nearest to history: of, in, and, the, as, one, by, was,
# Nearest to been: the, and, to, as, that, of, was, not,
# Nearest to as: of, to, a, in, and, the, not, that,
# Nearest to his: he, was, of, s, who, him, at, had,
# Nearest to where: to, a, the, is, and, which, that, for,
# Nearest to however: to, a, not, the, in, of, that, but,
# Nearest to which: to, that, the, and, a, of, this, not,
# Nearest to alternative: did, too, every, came, attempt, general, support, serious,
# Nearest to event: but, also, either, on, was, s, become, made,
# Nearest to ice: procurator, looters, canvas, pardon, haemoglobin, oxidation, ending, kcr,
# Nearest to heavy: since, group, degree, such, between, initially, officially, during,
# Nearest to powers: government, war, in, level, military, for, general, order,
# Nearest to accepted: work, to, being, should, through, time, for, considered,
# Nearest to brother: continued, once, been, came, great, saw, all, in,
# Nearest to universe: observer, j, formulated, existed, jocks, faded, remain, weight,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 9.3348 0.2950 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 9.3898 0.2935 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 9.6198 0.2925 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 9.4717 0.2934 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 9.2271 0.2933 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 9.2112 0.2931 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 9.4323 0.2933 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 9.3767 0.2932 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 8.9780 0.2941 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 9.1572 0.2928 sec/batch
# Nearest to for: the, of, to, by, as, and, a, in,
# Nearest to history: in, by, the, of, was, one, new, and,
# Nearest to been: the, to, of, in, and, a, by, their,
# Nearest to as: the, of, to, and, in, a, for, it,
# Nearest to his: he, was, him, the, had, in, of, who,
# Nearest to where: is, that, a, to, the, form, are, this,
# Nearest to however: that, to, a, not, it, an, in, the,
# Nearest to which: a, the, that, to, of, as, or, are,
# Nearest to alternative: in, particular, could, of, support, does, order, that,
# Nearest to event: who, own, on, among, no, but, may, only,
# Nearest to ice: canvas, looters, pardon, procurator, route, ending, haemoglobin, torrents,
# Nearest to heavy: degree, however, officially, nearly, forces, previous, between, tend,
# Nearest to powers: war, government, by, state, law, military, rule, term,
# Nearest to accepted: work, in, of, as, the, simply, though, not,
# Nearest to brother: he, himself, an, last, did, s, re, days,
# Nearest to universe: observer, john, j, faded, formulated, existed, minorities, weight,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 9.1403 0.2958 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 9.0633 0.2934 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 9.0616 0.2944 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 9.2704 0.2924 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 8.7912 0.2934 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 8.8814 0.2938 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 9.0138 0.2927 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 8.7729 0.2946 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 8.7873 0.2933 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 8.8615 0.2939 sec/batch
# Nearest to for: the, and, a, of, to, in, this, that,
# Nearest to history: and, in, the, were, of, th, by, was,
# Nearest to been: the, of, and, in, a, to, with, has,
# Nearest to as: the, of, and, to, a, this, in, its,
# Nearest to his: he, was, in, the, who, s, him, himself,
# Nearest to where: is, a, this, not, so, to, however, are,
# Nearest to however: the, and, this, a, to, not, of, by,
# Nearest to which: it, and, that, to, not, of, are, the,
# Nearest to alternative: get, since, longer, fact, own, his, particular, order,
# Nearest to event: almost, would, to, s, for, of, a, their,
# Nearest to ice: canvas, procurator, pardon, definitions, route, media, looters, wycliffe,
# Nearest to heavy: common, similar, body, its, several, greater, start, since,
# Nearest to powers: government, under, from, state, towards, civil, for, military,
# Nearest to accepted: this, in, as, who, that, of, it, did,
# Nearest to brother: had, who, later, he, was, died, her, at,
# Nearest to universe: observer, robert, existed, decade, see, theory, faded, formulated,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 8.8341 0.2951 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 8.4893 0.2933 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 8.5003 0.2929 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 8.7621 0.2943 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 8.7187 0.2942 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 8.6275 0.2936 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 9.0365 0.2933 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 8.3696 0.2933 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 8.6277 0.2932 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 8.6262 0.2925 sec/batch
# Nearest to for: the, in, to, and, on, of, a, as,
# Nearest to history: of, the, early, in, and, was, th, on,
# Nearest to been: the, to, in, that, for, have, a, on,
# Nearest to as: the, a, in, of, to, and, with, that,
# Nearest to his: he, had, was, him, later, s, the, himself,
# Nearest to where: a, it, that, the, in, is, to, as,
# Nearest to however: the, to, that, as, a, their, in, this,
# Nearest to which: a, the, as, is, this, for, in, on,
# Nearest to alternative: though, get, simply, serious, consider, applied, do, instead,
# Nearest to event: out, time, not, their, they, but, had, some,
# Nearest to ice: media, shown, with, canvas, he, therefore, placed, very,
# Nearest to heavy: taken, it, less, has, of, between, primarily, have,
# Nearest to powers: government, war, united, the, in, state, outside, power,
# Nearest to accepted: their, that, those, people, of, some, been, in,
# Nearest to brother: son, had, he, his, her, york, until, s,
# Nearest to universe: observer, existed, article, how, existing, formulated, model, faded,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 8.2319 0.2953 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 8.4519 0.2937 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 8.4050 0.2941 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 8.4163 0.2932 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 8.5438 0.2932 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 8.2485 0.2940 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 8.2330 0.2935 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 8.4644 0.2940 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 8.1406 0.2934 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 8.3146 0.2937 sec/batch
# Nearest to for: to, a, as, the, and, be, in, of,
# Nearest to history: of, was, in, the, by, s, great, and,
# Nearest to been: the, to, and, of, as, in, for, that,
# Nearest to as: the, of, and, to, a, for, in, an,
# Nearest to his: he, him, of, s, was, great, in, the,
# Nearest to where: as, the, is, a, and, be, to, of,
# Nearest to however: as, to, that, the, of, and, be, for,
# Nearest to which: the, as, a, to, be, it, and, of,
# Nearest to alternative: its, be, or, otherwise, has, was, to, serious,
# Nearest to event: of, as, on, out, to, in, and, made,
# Nearest to ice: media, regular, memorable, canvas, extensive, easier, shown, bring,
# Nearest to heavy: significant, from, around, people, increased, these, much, occurred,
# Nearest to powers: government, united, state, in, war, europe, led, members,
# Nearest to accepted: the, of, did, to, in, their, been, that,
# Nearest to brother: his, daughter, her, he, died, son, king, soon,
# Nearest to universe: observer, existed, theory, article, subject, general, perspective, re,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 8.1427 0.2952 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 7.9796 0.2939 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 8.0294 0.2932 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 8.0717 0.2931 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 8.0949 0.2936 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 7.6809 0.2935 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 7.7324 0.2938 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 7.7810 0.2932 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 7.9828 0.2930 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 7.9599 0.2927 sec/batch
# Nearest to for: to, of, a, the, in, on, has, an,
# Nearest to history: of, the, in, from, several, world, now, states,
# Nearest to been: to, with, in, of, the, from, have, as,
# Nearest to as: the, in, of, and, to, a, that, but,
# Nearest to his: he, was, him, had, who, s, in, great,
# Nearest to where: a, and, an, the, to, more, for, is,
# Nearest to however: to, that, and, of, some, the, as, have,
# Nearest to which: to, the, of, is, a, more, and, be,
# Nearest to alternative: in, result, approach, article, given, as, it, such,
# Nearest to event: of, the, would, as, to, in, could, on,
# Nearest to ice: actually, media, turning, directly, easier, combination, practically, aside,
# Nearest to heavy: within, less, around, more, being, group, also, during,
# Nearest to powers: government, act, war, political, did, states, members, power,
# Nearest to accepted: of, to, in, the, and, as, that, for,
# Nearest to brother: he, her, daughter, his, great, him, ii, young,
# Nearest to universe: establish, our, theory, suggested, matter, existed, remain, explain,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 7.6932 0.2952 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 7.8077 0.2931 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 7.8840 0.2931 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 7.8972 0.2932 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 7.6078 0.2933 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 7.5163 0.2937 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 7.6405 0.2931 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 7.6426 0.2936 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 7.5893 0.2934 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 7.7922 0.2931 sec/batch
# Nearest to for: a, to, the, on, it, in, as, by,
# Nearest to history: in, of, and, was, the, on, a, early,
# Nearest to been: the, to, of, that, in, and, as, with,
# Nearest to as: the, a, to, and, of, this, in, for,
# Nearest to his: he, who, him, was, her, men, father, s,
# Nearest to where: is, this, a, which, that, then, are, has,
# Nearest to however: this, that, it, the, not, to, is, a,
# Nearest to which: a, is, that, an, be, to, it, this,
# Nearest to alternative: there, that, be, as, such, it, which, for,
# Nearest to event: and, to, the, that, of, in, by, on,
# Nearest to ice: recognized, turning, made, reach, is, aside, narrow, simultaneously,
# Nearest to heavy: generally, may, made, occur, amount, often, power, have,
# Nearest to powers: government, of, the, political, members, by, authority, act,
# Nearest to accepted: in, that, it, of, to, as, with, the,
# Nearest to brother: king, her, he, she, himself, died, younger, daughter,
# Nearest to universe: matter, discussed, see, form, suggested, idea, how, describes,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 7.4306 0.2953 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 7.4168 0.2937 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 7.6491 0.2928 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 7.4923 0.2934 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 7.4903 0.2942 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 7.5213 0.2934 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 7.5354 0.2933 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 7.2015 0.2931 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 7.2690 0.2933 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 7.2850 0.2942 sec/batch
# Nearest to for: to, the, as, in, also, and, from, a,
# Nearest to history: of, world, th, early, great, in, and, was,
# Nearest to been: to, the, it, has, a, as, of, in,
# Nearest to as: to, the, which, a, it, of, and, for,
# Nearest to his: he, was, who, him, himself, death, her, wrote,
# Nearest to where: is, the, a, which, this, to, that, as,
# Nearest to however: to, as, this, the, it, not, or, be,
# Nearest to which: as, to, a, the, it, this, that, for,
# Nearest to alternative: be, or, to, such, it, has, for, used,
# Nearest to event: few, a, them, their, many, may, it, also,
# Nearest to ice: below, down, amounts, gives, narrow, increases, inside, entire,
# Nearest to heavy: has, it, few, almost, less, much, such, also,
# Nearest to powers: government, were, the, state, war, held, and, of,
# Nearest to accepted: not, as, that, with, of, it, others, what,
# Nearest to brother: king, daughter, son, his, mother, younger, he, died,
# Nearest to universe: idea, matter, our, explanation, theory, suggested, explain, physical,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 7.4750 0.2961 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 7.4077 0.2935 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 7.5996 0.2931 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 7.2878 0.2939 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 7.2337 0.2928 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 7.4739 0.2926 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 7.1592 0.2932 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 7.1240 0.2942 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 7.1710 0.2934 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 7.2554 0.2937 sec/batch
# Nearest to for: to, the, as, in, and, of, a, on,
# Nearest to history: of, in, and, century, the, by, th, early,
# Nearest to been: to, the, and, for, of, as, a, most,
# Nearest to as: of, to, for, the, and, in, a, that,
# Nearest to his: he, him, was, who, death, whom, she, her,
# Nearest to where: a, in, of, to, as, it, that, the,
# Nearest to however: to, the, but, for, their, as, in, an,
# Nearest to which: to, a, this, be, is, it, that, as,
# Nearest to alternative: more, most, this, to, that, which, have, will,
# Nearest to event: the, out, to, of, for, on, by, came,
# Nearest to ice: below, narrow, ground, increases, turning, down, beyond, contact,
# Nearest to heavy: and, although, than, less, it, almost, still, small,
# Nearest to powers: government, majority, authority, nations, war, state, governments, were,
# Nearest to accepted: of, that, to, practice, term, because, in, the,
# Nearest to brother: son, father, daughter, he, his, king, died, mother,
# Nearest to universe: our, matter, explanation, how, theory, physics, principle, subject,
# Epoch 5/10 Iteration: 23100 Avg. Training loss: 7.3020 0.2951 sec/batch
# Epoch 6/10 Iteration: 23200 Avg. Training loss: 7.1276 0.2208 sec/batch
# Epoch 6/10 Iteration: 23300 Avg. Training loss: 7.0831 0.2937 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 7.1962 0.2935 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 7.0072 0.2943 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 7.1414 0.2934 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 7.0720 0.2938 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 6.8410 0.2934 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 7.0099 0.2938 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 6.9758 0.2931 sec/batch
# Nearest to for: to, a, the, or, an, all, and, as,
# Nearest to history: in, by, of, the, and, world, was, early,
# Nearest to been: to, in, the, of, by, that, and, this,
# Nearest to as: to, the, in, of, and, that, a, for,
# Nearest to his: he, him, was, who, himself, after, whom, later,
# Nearest to where: of, to, that, a, it, as, which, the,
# Nearest to however: to, the, this, an, a, that, as, not,
# Nearest to which: to, that, it, the, is, of, this, an,
# Nearest to alternative: such, that, which, to, a, by, has, been,
# Nearest to event: the, on, s, of, to, was, in, and,
# Nearest to ice: entire, around, down, range, below, ground, on, greatly,
# Nearest to heavy: a, small, almost, to, with, which, down, due,
# Nearest to powers: government, political, state, did, under, united, led, held,
# Nearest to accepted: but, accept, that, of, work, have, in, who,
# Nearest to brother: father, daughter, son, his, he, him, mother, died,
# Nearest to universe: observed, matter, theory, our, explanation, exist, principle, suggested,
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 7.0422 0.2957 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 6.7105 0.2933 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 6.6465 0.2931 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 6.7573 0.2937 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 6.8929 0.2927 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 6.9864 0.2934 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 6.7775 0.2931 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 6.7686 0.2935 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 6.7030 0.2932 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 6.8208 0.2935 sec/batch
# Nearest to for: the, a, to, and, on, of, as, it,
# Nearest to history: late, in, early, of, references, was, new, world,
# Nearest to been: to, the, and, of, in, by, it, their,
# Nearest to as: the, and, in, to, of, with, it, for,
# Nearest to his: he, him, who, was, died, himself, father, she,
# Nearest to where: the, that, a, to, it, is, as, some,
# Nearest to however: the, as, is, of, in, and, some, to,
# Nearest to which: the, is, that, some, to, or, this, it,
# Nearest to alternative: other, and, in, that, as, some, the, for,
# Nearest to event: at, to, and, the, in, it, many, of,
# Nearest to ice: surface, hot, range, water, peak, temperature, feet, low,
# Nearest to heavy: equipment, less, large, high, the, range, able, while,
# Nearest to powers: government, political, rule, governments, majority, state, held, affairs,
# Nearest to accepted: the, religious, view, and, self, claim, practice, adopted,
# Nearest to brother: died, father, he, his, son, daughter, wife, mother,
# Nearest to universe: matter, physical, theory, explanation, physics, suggested, observations, exist,
# Epoch 6/10 Iteration: 25100 Avg. Training loss: 6.7815 0.2953 sec/batch
# Epoch 6/10 Iteration: 25200 Avg. Training loss: 6.5087 0.2931 sec/batch
# Epoch 6/10 Iteration: 25300 Avg. Training loss: 6.7579 0.2934 sec/batch
# Epoch 6/10 Iteration: 25400 Avg. Training loss: 6.7487 0.2931 sec/batch
# Epoch 6/10 Iteration: 25500 Avg. Training loss: 6.5948 0.2941 sec/batch
# Epoch 6/10 Iteration: 25600 Avg. Training loss: 6.7999 0.2926 sec/batch
# Epoch 6/10 Iteration: 25700 Avg. Training loss: 6.5931 0.2939 sec/batch
# Epoch 6/10 Iteration: 25800 Avg. Training loss: 6.4103 0.2935 sec/batch
# Epoch 6/10 Iteration: 25900 Avg. Training loss: 6.6939 0.2935 sec/batch
# ...
# Nearest to which: to, of, a, as, this, the, it, in,
# Nearest to alternative: comprehensive, widely, various, such, or, use, that, example,
# Nearest to event: to, the, at, reach, a, more, once, and,
# Nearest to ice: snow, winter, frozen, covered, summer, mountain, hot, meters,
# Nearest to heavy: mounted, fire, lighter, during, high, enemy, large, on,
# Nearest to powers: affairs, government, constitutional, monarchy, power, governments, under, ruling,
# Nearest to accepted: believe, attributed, accept, view, claim, christians, that, not,
# Nearest to brother: his, him, father, daughter, died, wife, married, sons,
# Nearest to universe: observations, matter, theory, hypothesis, observed, physics, explain, mechanics,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 5.1009 0.2952 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 5.1349 0.2937 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 5.1712 0.2933 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 5.2514 0.2932 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 5.3428 0.2929 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 5.1973 0.2930 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 5.2448 0.2935 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 5.2539 0.2929 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 5.3542 0.2934 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 5.2012 0.2932 sec/batch
# Nearest to for: to, the, on, a, and, in, an, more,
# Nearest to history: historical, century, early, references, encyclopedia, of, th, press,
# Nearest to been: and, by, to, of, in, as, it, being,
# Nearest to as: and, in, of, to, the, which, more, with,
# Nearest to his: he, him, himself, who, she, man, died, was,
# Nearest to where: the, a, is, above, given, by, there, which,
# Nearest to however: to, is, that, some, it, the, this, there,
# Nearest to which: the, a, and, as, that, to, is, of,
# Nearest to alternative: such, variety, use, other, as, more, on, examples,
# Nearest to event: to, the, in, out, a, and, would, of,
# Nearest to ice: snow, dry, hot, water, covered, ground, rock, summer,
# Nearest to heavy: lighter, metal, mounted, weapons, high, fast, fire, heavier,
# Nearest to powers: constitutional, rule, government, monarchy, ruling, parliamentary, legislature, political,
# Nearest to accepted: practice, view, society, social, debate, origins, consensus, tradition,
# Nearest to brother: his, sons, father, her, wife, son, she, whom,
# Nearest to universe: observations, matter, explanation, existence, hypothesis, theory, our, reality,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 5.1305 0.2955 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 5.2179 0.2932 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 5.2373 0.2936 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 5.1863 0.2936 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 5.3313 0.2928 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 5.1251 0.2937 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 5.1035 0.2933 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 5.2279 0.2935 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 5.1496 0.2935 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 5.1590 0.2941 sec/batch
# Nearest to for: and, to, in, of, a, all, on, the,
# Nearest to history: historical, th, external, of, in, modern, comprehensive, early,
# Nearest to been: to, in, and, of, the, a, with, has,
# Nearest to as: of, the, to, and, in, with, there, a,
# Nearest to his: he, who, himself, him, father, wrote, her, later,
# Nearest to where: a, with, is, called, of, the, and, to,
# Nearest to however: not, to, all, it, their, that, the, a,
# Nearest to which: that, a, to, this, not, and, of, it,
# Nearest to alternative: such, related, be, this, these, use, examples, form,
# Nearest to event: of, end, on, the, events, times, time, known,
# Nearest to ice: snow, hot, dry, water, covered, rock, wet, winter,
# Nearest to heavy: lighter, mounted, metal, steel, quickly, down, heavier, weight,
# Nearest to powers: formally, constitutional, state, exercised, political, power, led, government,
# Nearest to accepted: scholars, religion, ideas, matters, society, tradition, view, regard,
# Nearest to brother: son, died, wife, sons, father, cousin, daughter, uncle,
# Nearest to universe: observations, matter, theory, explanation, nature, existence, astronomy, physical,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 5.1709 0.2951 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 5.1764 0.2935 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 4.9757 0.2934 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 5.0935 0.2933 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 5.0819 0.2942 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 5.1632 0.2937 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 5.2331 0.2941 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 5.3507 0.2932 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 5.1425 0.2935 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 5.0738 0.2928 sec/batch
# Nearest to for: as, the, to, an, and, with, a, that,
# Nearest to history: historical, links, th, external, early, press, library, world,
# Nearest to been: the, in, to, for, of, that, as, which,
# Nearest to as: the, to, of, and, in, for, with, a,
# Nearest to his: he, him, was, father, himself, had, who, received,
# Nearest to where: a, the, at, with, called, then, in, as,
# Nearest to however: as, the, to, for, that, it, of, and,
# Nearest to which: and, that, a, to, of, this, for, as,
# Nearest to alternative: for, widely, often, e, examples, a, more, or,
# Nearest to event: out, times, events, all, they, the, time, never,
# Nearest to ice: snow, hot, winter, summer, deep, temperatures, frozen, covered,
# Nearest to heavy: metal, bands, rock, mounted, high, steel, black, long,
# Nearest to powers: power, sovereign, affairs, treaties, rule, constitution, independent, formally,
# Nearest to accepted: view, views, religious, those, that, practice, religion, important,
# Nearest to brother: son, father, daughter, king, younger, married, sister, throne,
# Nearest to universe: observations, matter, reality, cosmology, explanation, astronomy, theory, explained,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 5.2310 0.2944 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 5.0847 0.2929 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 5.0598 0.2938 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 5.0396 0.2935 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 5.1138 0.2937 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 5.1951 0.2933 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 5.0752 0.2203 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 5.0577 0.2942 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 5.1574 0.2935 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 5.0381 0.2942 sec/batch
# Nearest to for: as, to, a, on, with, an, the, its,
# Nearest to history: century, of, th, external, historical, modern, library, links,
# Nearest to been: to, the, and, have, in, but, it, with,
# Nearest to as: with, a, or, the, in, to, and, other,
# Nearest to his: he, him, who, father, himself, whom, was, died,
# Nearest to where: a, the, which, as, called, of, in, and,
# Nearest to however: to, than, be, but, as, for, these, have,
# Nearest to which: the, in, a, to, as, with, of, and,
# Nearest to alternative: based, specific, conventional, available, approaches, related, method, particular,
# Nearest to event: by, out, on, times, the, ever, up, at,
# Nearest to ice: snow, winter, summer, covered, hot, frozen, rocks, rock,
# Nearest to heavy: metal, almost, steel, air, mounted, lead, down, lighter,
# Nearest to powers: constitution, formally, sovereign, under, constitutional, affairs, parliament, advice,
# Nearest to accepted: that, adherents, discussed, not, regard, accept, contrary, law,
# Nearest to brother: son, father, cousin, daughter, wife, married, his, younger,
# Nearest to universe: observations, matter, reality, observed, cosmology, theory, explain, hypothesis,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 5.0822 0.2953 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 5.1217 0.2935 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 4.9241 0.2933 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 5.0147 0.2933 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 5.0134 0.2932 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 5.0895 0.2931 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 4.9159 0.2935 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 4.8475 0.2930 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 4.9298 0.2937 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 4.9528 0.2927 sec/batch
# Nearest to for: the, in, of, to, as, and, by, all,
# Nearest to history: links, article, of, external, encyclopedia, page, historical, references,
# Nearest to been: to, become, as, the, from, some, and, were,
# Nearest to as: the, and, of, in, some, to, which, have,
# Nearest to his: he, him, himself, friend, wife, who, was, father,
# Nearest to where: the, a, time, only, are, which, called, by,
# Nearest to however: to, but, that, the, result, all, not, for,
# Nearest to which: the, a, be, to, that, this, or, an,
# Nearest to alternative: based, include, available, article, comprehensive, this, modern, a,
# Nearest to event: at, times, time, reach, out, during, over, beyond,
# Nearest to ice: snow, hot, winter, frozen, water, dry, temperatures, covered,
# Nearest to heavy: lighter, down, tanks, due, steel, around, huge, metal,
# Nearest to powers: constitutional, government, monarchy, constitution, ministers, supreme, formally, governments,
# Nearest to accepted: religious, accept, as, christian, authority, knowledge, regard, beliefs,
# Nearest to brother: son, he, cousin, his, daughter, wife, him, mother,
# Nearest to universe: observations, matter, theory, cosmology, explanation, existence, cosmic, our,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 5.0466 0.2953 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 4.9455 0.2932 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 4.9690 0.2937 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 4.9482 0.2931 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 4.9960 0.2927 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 5.0454 0.2937 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 4.8315 0.3004 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 4.9715 0.2961 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 4.9619 0.2929 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 4.9059 0.2939 sec/batch
# Nearest to for: a, with, to, more, on, the, has, that,
# Nearest to history: links, historical, external, origins, online, see, of, encyclopedia,
# Nearest to been: to, in, that, has, and, other, have, of,
# Nearest to as: to, which, and, is, that, with, a, has,
# Nearest to his: he, him, who, himself, friend, her, wife, young,
# Nearest to where: is, a, there, from, the, above, which, as,
# Nearest to however: that, this, to, it, not, as, the, which,
# Nearest to which: with, as, to, that, it, is, and, the,
# Nearest to alternative: see, related, information, article, these, various, concepts, based,
# Nearest to event: times, the, a, in, its, over, there, large,
# Nearest to ice: snow, frozen, covered, hot, water, rocks, rain, dry,
# Nearest to heavy: heavier, lighter, mounted, due, quickly, very, metal, during,
# Nearest to powers: constitutional, governments, held, constitution, government, war, monarchy, political,
# Nearest to accepted: concerned, religious, doctrine, that, religion, knowledge, of, those,
# Nearest to brother: son, sons, cousin, younger, daughter, died, heir, her,
# Nearest to universe: observations, cosmology, cosmic, matter, astronomy, explain, mass, reality,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 5.0330 0.2951 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 4.8923 0.2938 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 4.8090 0.2932 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 4.9327 0.2930 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 4.9559 0.2938 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 4.8894 0.2936 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 4.8724 0.2941 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 4.9468 0.2933 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 4.7580 0.2935 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 4.8310 0.2926 sec/batch
# Nearest to for: in, of, to, an, also, on, as, and,
# Nearest to history: th, historical, culture, western, world, see, cultural, earliest,
# Nearest to been: and, in, their, it, various, to, were, of,
# Nearest to as: to, the, of, in, or, a, it, other,
# Nearest to his: he, him, father, wife, himself, death, brother, younger,
# Nearest to where: a, the, is, as, left, it, to, then,
# Nearest to however: to, it, the, but, in, this, as, which,
# Nearest to which: the, of, to, by, as, it, but, and,
# Nearest to alternative: for, widely, based, include, technical, these, such, see,
# Nearest to event: times, events, both, ever, on, very, time, an,
# Nearest to ice: snow, winter, rain, outdoor, hockey, wind, hot, rock,
# Nearest to heavy: metal, steel, bands, heavier, rock, cutting, tracks, quickly,
# Nearest to powers: constitutional, constitution, governments, war, monarchy, under, rule, declare,
# Nearest to accepted: among, religious, catholic, practice, religion, doctrine, view, christian,
# Nearest to brother: cousin, younger, daughter, son, her, mother, married, sister,
# Nearest to universe: observations, cosmic, cosmology, reality, explain, earth, existence, worlds,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 4.8353 0.2961 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 4.8887 0.2943 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 4.9341 0.2938 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 5.0276 0.2937 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 5.0718 0.2927 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 4.7936 0.2936 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 4.9321 0.2921 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 4.9278 0.2933 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 4.7921 0.2934 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 4.8268 0.2937 sec/batch
# Nearest to for: the, in, to, an, on, with, a, of,
# Nearest to history: historical, of, th, culture, origins, century, modern, early,
# Nearest to been: the, has, to, however, well, of, their, but,
# Nearest to as: of, the, and, in, to, but, an, this,
# Nearest to his: he, him, himself, who, was, wife, whom, her,
# Nearest to where: a, as, the, in, from, to, it, of,
# Nearest to however: the, but, that, to, of, them, their, not,
# Nearest to which: an, the, as, this, a, to, be, it,
# Nearest to alternative: based, available, online, information, systems, application, comprehensive, content,
# Nearest to event: once, out, last, time, winning, played, single, end,
# Nearest to ice: snow, winter, summer, rock, frozen, waters, deep, hot,
# Nearest to heavy: metal, steel, cutting, bands, rock, underground, almost, lead,
# Nearest to powers: formally, power, government, constitution, sovereign, under, supremacy, governed,
# Nearest to accepted: views, view, religious, of, accept, doctrine, ideas, regard,
# Nearest to brother: son, daughter, father, wife, married, cousin, his, queen,
# Nearest to universe: cosmic, reality, cosmology, matter, observations, explain, fictional, existence,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 4.8520 0.2953 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 4.8796 0.2934 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# WARNING:tensorflow:From C:\Users\lenovo lappy\.conda\envs\keras-gpu\lib\site-packages\tensorflow\python\training\saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
import matplotlib
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
